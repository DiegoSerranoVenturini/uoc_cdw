# %% [markdown]
# # Caso practico 1
#
# ## Requerimientos
#
# - Realizar el análisis funcional de los requerimientos de dados.
# - Identificar los elementos de análisis (indicadores, hechos, dimensiones, atributos).
# - Analizar las fuentes de datos del entorno operacional proporcionados.
# - Realizar el diseño completo (conceptual, lógico y físico) hasta obtener el modelo multidimensional del Data Warehouse.

# %% [markdown]
# ## Lectura de datos

# %%
import pandas as pd
import numpy as np
import os
import json
import xmltodict

# %%
data_airlines = pd.read_csv('../../PRA1-Datos/airlines.dat', sep=",", encoding='latin1', header=None)
data_airlines.head()
#data_airlines.shape
# Out:
#    0                                             1   2    3    4        5  \
# 0  1                                Private flight  \N    -  NaN      NaN
# 1  2                                   135 Airways  \N  NaN  GNL  GENERAL
# 2  3                                 1Time Airline  \N   1T  RNX  NEXTIME
# 3  4  2 Sqn No 1 Elementary Flying Training School  \N  NaN  WYT      NaN
# 4  5                               213 Flight Unit  \N  NaN  TFU      NaN
#
#                 6  7
# 0             NaN  Y
# 1   United States  N
# 2    South Africa  Y
# 3  United Kingdom  N
# 4          Russia  N

# %%
data_airports = pd.read_csv('../../PRA1-Datos/airports.dat', sep=",", encoding='latin1', header=None)
data_airports.head()
# Out:
#    0                           1             2                 3    4     5   \
# 0   1                      Goroka        Goroka  Papua New Guinea  GKA  AYGA
# 1   2                      Madang        Madang  Papua New Guinea  MAG  AYMD
# 2   3                 Mount Hagen   Mount Hagen  Papua New Guinea  HGU  AYMH
# 3   4                      Nadzab        Nadzab  Papua New Guinea  LAE  AYNZ
# 4   5  Port Moresby Jacksons Intl  Port Moresby  Papua New Guinea  POM  AYPY
#
#          6           7     8     9  10                    11
# 0 -6.081689  145.391881  5282  10.0  U  Pacific/Port_Moresby
# 1 -5.207083  145.788700    20  10.0  U  Pacific/Port_Moresby
# 2 -5.826789  144.295861  5388  10.0  U  Pacific/Port_Moresby
# 3 -6.569828  146.726242   239  10.0  U  Pacific/Port_Moresby
# 4 -9.443383  147.220050   146  10.0  U  Pacific/Port_Moresby

# %%
data_routes = pd.read_csv('../../PRA1-Datos/routes.dat', sep=",", encoding='latin1', header=None)
data_routes.head()
# Out:
#     0    1    2     3    4     5    6  7    8
# 0  2B  410  AER  2965  KZN  2990  NaN  0  CR2
# 1  2B  410  ASF  2966  KZN  2990  NaN  0  CR2
# 2  2B  410  ASF  2966  MRV  2962  NaN  0  CR2
# 3  2B  410  CEK  2968  KZN  2990  NaN  0  CR2
# 4  2B  410  CEK  2968  OVB  4078  NaN  0  CR2

# %%
data_annual_contry_ext_commerce = pd.read_csv('../../PRA1-Datos/worldbank_comercio_ext_anual_pais.csv', sep=",", encoding='latin1')
data_annual_contry_ext_commerce.head()
# Out:
#   Country Name Country Code    Indicator Name  Indicator Code       1960  \
# 0        Aruba          ABW  Trade (% of GDP)  NE.TRD.GNFS.ZS        NaN
# 1  Afghanistan          AFG  Trade (% of GDP)  NE.TRD.GNFS.ZS  11.157027
# 2       Angola          AGO  Trade (% of GDP)  NE.TRD.GNFS.ZS        NaN
# 3      Albania          ALB  Trade (% of GDP)  NE.TRD.GNFS.ZS        NaN
# 4      Andorra          AND  Trade (% of GDP)  NE.TRD.GNFS.ZS        NaN
#
#        1961       1962       1963       1964       1965     ...       \
# 0       NaN        NaN        NaN        NaN        NaN     ...
# 1  12.55061  14.227644  26.035511  26.944448  32.671083     ...
# 2       NaN        NaN        NaN        NaN        NaN     ...
# 3       NaN        NaN        NaN        NaN        NaN     ...
# 4       NaN        NaN        NaN        NaN        NaN     ...
#
#          2009        2010        2011        2012       2013       2014  \
# ...

# %%
data_annual_contry_ing_turism = pd.read_csv('../../PRA1-Datos/worldbank_ing_turismo_anual_pais.csv', sep=",", encoding='latin1')
data_annual_contry_ing_turism.head()
# Out:
#   Country Name Country Code                                 Indicator Name  \
# 0        Aruba          ABW  International tourism, receipts (current US$)
# 1  Afghanistan          AFG  International tourism, receipts (current US$)
# 2       Angola          AGO  International tourism, receipts (current US$)
# 3      Albania          ALB  International tourism, receipts (current US$)
# 4      Andorra          AND  International tourism, receipts (current US$)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965     ...       \
# 0  ST.INT.RCPT.CD   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 1  ST.INT.RCPT.CD   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 2  ST.INT.RCPT.CD   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 3  ST.INT.RCPT.CD   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 4  ST.INT.RCPT.CD   NaN   NaN   NaN   NaN   NaN   NaN     ...
#
#            2009          2010          2011          2012          2013  \
# ...

# %%
data_annual_contry_passengers = pd.read_csv('../../PRA1-Datos/worldbank_pasajeros_anual_pais.csv', sep=",", encoding='latin1')
data_annual_contry_passengers.head()
# Out:
#   Country Code                    Indicator Name Indicator Code  1960  1961  \
# 0          ABW  Air transport passengers carried    IS.AIR.PSGR   NaN   NaN
# 1          AND  Air transport passengers carried    IS.AIR.PSGR   NaN   NaN
# 2          AFG  Air transport passengers carried    IS.AIR.PSGR   NaN   NaN
# 3          AGO  Air transport passengers carried    IS.AIR.PSGR   NaN   NaN
# 4          ALB  Air transport passengers carried    IS.AIR.PSGR   NaN   NaN
#
#    1962  1963  1964  1965  1966 ...              2007             2008  \
# 0   NaN   NaN   NaN   NaN   NaN ...
# 1   NaN   NaN   NaN   NaN   NaN ...
# 2   NaN   NaN   NaN   NaN   NaN ...
# 3   NaN   NaN   NaN   NaN   NaN ...            277361           283887
# 4   NaN   NaN   NaN   NaN   NaN ...            238913           243691
#
#               2009             2010             2011             2012  \
# 0
# 1
# 2                           1999127        2279341.2        1737962.1
# ...

# %%
data_annual_contry_population = pd.read_csv('../../PRA1-Datos/worldbank_poblacion_anual_pais.csv', sep=",", encoding='latin1')
data_annual_contry_population.head()
# Out:
#   Country Code        Indicator Name  Indicator Code     1960     1961  \
# 0          ABW  Population, total     SP.POP.TOTL       54208    55435
# 1          AND  Population, total     SP.POP.TOTL       13414    14376
# 2          AFG  Population, total     SP.POP.TOTL     8994793  9164945
# 3          AGO  Population, total     SP.POP.TOTL     5270844  5367287
# 4          ALB  Population, total     SP.POP.TOTL     1608800  1659800
#
#       1962     1963     1964     1965      1966       ...             2007  \
# 0    56226    56697    57029    57360     57712       ...           101218
# 1    15376    16410    17470    18551     19646       ...            84878
# 2  9343772  9531555  9728645  9935358  10148841       ...         25877544
# 3  5465905  5565808  5665701  5765025   5863568       ...         19183907
# 4  1711319  1762621  1814135  1864791   1914573       ...          2970017
#
#        2008      2009      2010      2011      2012      2013      2014  \
# ...

# %%
with open('../../PRA1-Datos/equipamientos.js', 'rt') as f:
    data_equipment = json.loads(f.read())
data_equipment
# Out:
# {'equipamientos': [{'desc_equipamiento': 'Fokker 100                                    ',
#    'cod_equipamiento': '100'},
#   {'desc_equipamiento': 'BAe 146-100 Pax                               ',
#    'cod_equipamiento': '141'},
#   {'desc_equipamiento': 'BAe 146-200 Pax                               ',
#    'cod_equipamiento': '142'},
#   {'desc_equipamiento': 'BAe 146-300 Pax                               ',
#    'cod_equipamiento': '143'},
#   {'desc_equipamiento': 'BAe 146 all pax models                        ',
#    'cod_equipamiento': '146'},
#   {'desc_equipamiento': 'BAe 146 Freighter (-100/200/300QT & QC)       ',
#    'cod_equipamiento': '14F'},
#   {'desc_equipamiento': 'BAe 146 Freighter (-100QT & QC)               ',
#    'cod_equipamiento': '14X'},
#   {'desc_equipamiento': 'BAe 146 Freighter (-200QT & QC)               ',
#    'cod_equipamiento': '14Y'},
#   {'desc_equipamiento': 'BAe 146 Freighter (-200QT & QC)               ',
#    'cod_equipamiento': '14Z'},
# ...

# %%
with open('../../PRA1-Datos/paises.xml', 'rt') as f:
    data_countries = xmltodict.parse(f.read())
data_countries
# Out:
# OrderedDict([('paises',
#               OrderedDict([('row',
#                             [OrderedDict([('cod_pais', 'AFG'),
#                                           ('cod_pais2', 'AF'),
#                                           ('desc_pais', 'Afghanistan'),
#                                           ('cod_continente', 'AS'),
#                                           ('desc_continente', 'Asia'),
#                                           ('latitude', '33.9'),
#                                           ('longitude', '67.7')]),
#                              OrderedDict([('cod_pais', 'ALB'),
#                                           ('cod_pais2', 'AL'),
#                                           ('desc_pais', 'Albania'),
#                                           ('cod_continente', 'EU'),
#                                           ('desc_continente', 'Europe'),
#                                           ('latitude', '41.2'),
# ...
